# %%
import pandas as pd

data = pd.read_csv("roadmap_crawler/parsed_data_raw/processed_csv/frontend_processed.csv")
data
# Out:
#        Target Category                                             Skill  \
# 0    frontend  roadmap  Continue Learning with following relevant tracks
# 1    frontend  roadmap                                         Front-end
# 2    frontend  roadmap                                          Internet
# 3    frontend  roadmap                       How does the internet work?
# 4    frontend  roadmap                                     What is HTTP?
# ..        ...      ...                                               ...
# 126  frontend  roadmap                                             Astro
# 127  frontend  roadmap                                      Browser APIs
# 128  frontend  roadmap                           Measure & Improve Perf.
# 129  frontend  roadmap                                         Fullstack
# 130  frontend  roadmap                   Visit Beginner Friendly Version
#
#                   Parent     Group       Type
# ...
